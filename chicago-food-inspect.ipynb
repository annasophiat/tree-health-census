# %% [markdown]
# Data Source: https://data.cityofchicago.org/Health-Human-Services/Food-Inspections/4ijn-s7e5

# %%
import pandas as pd
import json
from pandas.io.json import json_normalize
import requests

# %%
url = 'https://data.cityofchicago.org/resource/4ijn-s7e5.json'

r = requests.get(url)
data = r.json()

# %%
json_normalize(data) # 1000 rows × 24 columns
# Out:
#     :@computed_region_43wa_7qmu :@computed_region_6mkv_f3dw  \
# 0                            36                        4446
# 1                            36                        4446
# 2                             9                        4301
# 3                            36                        4446
# 4                            43                       21861
# 5                             5                       21853
# 6                            24                        4450
# 7                            36                        4446
# 8                            18                       22616
# 9                            31                       22257
# 10                           36                        4446
# 11                           36                        4446
# 12                           36                        4446
# 13                           18                       21538
# 14                           44                       22615
# ...

# %%
len(data)
# Out:
# 1000

# %%
data[0]
# Out:
# {'inspection_id': '2304327',
#  'dba_name': 'EUROSTARS MAGNIFICENT MILE',
#  'aka_name': 'PORTSMITH/APOGEE',
#  'license_': '2677435',
#  'facility_type': 'Restaurant',
#  'risk': 'Risk 3 (Low)',
#  'address': '660 N STATE ST',
#  'city': 'CHICAGO',
#  'state': 'IL',
#  'zip': '60654',
#  'inspection_date': '2019-08-08T00:00:00.000',
#  'inspection_type': 'License',
#  'results': 'Pass',
#  'latitude': '41.89418322482492',
#  'longitude': '-87.62828580708',
#  'location': {'latitude': '41.89418322482492',
#   'longitude': '-87.62828580708',
#   'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'},
#  ':@computed_region_awaf_s7ux': '22',
#  ':@computed_region_6mkv_f3dw': '4446',
#  ':@computed_region_vrxf_vc4k': '37',
#  ':@computed_region_bdys_3d7i': '669',
#  ':@computed_region_43wa_7qmu': '36'}
